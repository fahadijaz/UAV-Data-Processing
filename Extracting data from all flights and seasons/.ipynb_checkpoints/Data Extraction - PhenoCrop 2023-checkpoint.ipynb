# %%
import pandas as pd
from datetime import datetime
import glob
import os
import math

# To be able to read XLS files
# pip install xlrd

# %%
path_qgis = r'C:\Users\muij\OneDrive - Norwegian University of Life Sciences\Documents\+Combining ALL DATA with Agro\PhenoCrop 2023'

# %%
path_agro = r'C:\Users\muij\OneDrive - Norwegian University of Life Sciences\Documents\+Combining ALL DATA with Agro\PhenoCrop 2023\AGRO DATA 2023'

# %%
all_files_qgis = glob.glob(path_qgis + "/*.xlsx")
all_files_qgis
# Out:
# ['C:\\Users\\muij\\OneDrive - Norwegian University of Life Sciences\\Documents\\+Combining ALL DATA with Agro\\PhenoCrop 2023\\phenocrop-2023-P4M-20m-20230623.xlsx',
#  'C:\\Users\\muij\\OneDrive - Norwegian University of Life Sciences\\Documents\\+Combining ALL DATA with Agro\\PhenoCrop 2023\\phenocrop-2023-P4M-20m-20230628.xlsx',
#  'C:\\Users\\muij\\OneDrive - Norwegian University of Life Sciences\\Documents\\+Combining ALL DATA with Agro\\PhenoCrop 2023\\phenocrop-2023-P4M-20m-20230708.xlsx',
#  'C:\\Users\\muij\\OneDrive - Norwegian University of Life Sciences\\Documents\\+Combining ALL DATA with Agro\\PhenoCrop 2023\\phenocrop-2023-P4M-20m-20230714.xlsx',
#  'C:\\Users\\muij\\OneDrive - Norwegian University of Life Sciences\\Documents\\+Combining ALL DATA with Agro\\PhenoCrop 2023\\phenocrop-2023-P4M-20m-20230719.xlsx',
#  'C:\\Users\\muij\\OneDrive - Norwegian University of Life Sciences\\Documents\\+Combining ALL DATA with Agro\\PhenoCrop 2023\\phenocrop-2023-P4M-20m-20230727.xlsx',
#  'C:\\Users\\muij\\OneDrive - Norwegian University of Life Sciences\\Documents\\+Combining ALL DATA with Agro\\PhenoCrop 2023\\phenocrop-M3MS-20m-20230614.xlsx',
#  'C:\\Users\\muij\\OneDrive - Norwegian University of Life Sciences\\Documents\\+Combining ALL DATA with Agro\\PhenoCrop 2023\\Phenocrop-M3MS-20m-20230622.xlsx',
#  'C:\\Users\\muij\\OneDrive - Norwegian University of Life Sciences\\Documents\\+Combining ALL DATA with Agro\\PhenoCrop 2023\\phenocrop-M3MS-20m-20230628.xlsx',
#  'C:\\Users\\muij\\OneDrive - Norwegian University of Life Sciences\\Documents\\+Combining ALL DATA with Agro\\PhenoCrop 2023\\phenocrop-M3MS-20m-20230708.xlsx',
#  'C:\\Users\\muij\\OneDrive - Norwegian University of Life Sciences\\Documents\\+Combining ALL DATA with Agro\\PhenoCrop 2023\\phenocrop-M3MS-20m-20230714.xlsx']

# %%
# Importing all the datasets except those from Mavic3RGB images since we need the Multispectral data only

list_df_names = []
for filepath in all_files_qgis:
    if not("M3RGB") in filepath:
        file_name=os.path.basename(filepath[:-5]).replace('-','_')
        list_df_names.append(file_name)
        
        # print(filepath,os.path.basename(filepath[:-5]))
        locals()[file_name] = pd.read_excel(filepath, index_col=None, header=0)
        print(file_name, '=====', locals()[file_name].shape)
# Out:
# phenocrop_2023_P4M_20m_20230623 ===== (760, 19)
# phenocrop_2023_P4M_20m_20230628 ===== (760, 19)
# phenocrop_2023_P4M_20m_20230708 ===== (760, 28)
# phenocrop_2023_P4M_20m_20230714 ===== (760, 16)
# phenocrop_2023_P4M_20m_20230719 ===== (760, 19)
# phenocrop_2023_P4M_20m_20230727 ===== (760, 19)
# phenocrop_M3MS_20m_20230614 ===== (760, 16)
# Phenocrop_M3MS_20m_20230622 ===== (760, 16)
# phenocrop_M3MS_20m_20230628 ===== (760, 16)
# phenocrop_M3MS_20m_20230708 ===== (760, 16)
# phenocrop_M3MS_20m_20230714 ===== (760, 16)

# %%
# Since one dataset has more than 19 columns,
# and after checking them manually it was found that the ones after the 19th columns are not relevant,
# keeping only the first 19 columns here.

for dfs in list_df_names:
    # print(dfs, locals()[dfs].shape)
    locals()[dfs] = locals()[dfs].iloc[:,:19]
    print(dfs, locals()[dfs].shape)
# Out:
# phenocrop_2023_P4M_20m_20230623 (760, 19)
# phenocrop_2023_P4M_20m_20230628 (760, 19)
# phenocrop_2023_P4M_20m_20230708 (760, 19)
# phenocrop_2023_P4M_20m_20230714 (760, 16)
# phenocrop_2023_P4M_20m_20230719 (760, 19)
# phenocrop_2023_P4M_20m_20230727 (760, 19)
# phenocrop_M3MS_20m_20230614 (760, 16)
# Phenocrop_M3MS_20m_20230622 (760, 16)
# phenocrop_M3MS_20m_20230628 (760, 16)
# phenocrop_M3MS_20m_20230708 (760, 16)
# phenocrop_M3MS_20m_20230714 (760, 16)

# %% [markdown]
# # One dataset has blue values missing. Will have to fix that processing in QGIS later. Right now moving forward with the missing values.

# %% [markdown]
# # Adding date column

# %%
# Adding respective date column in each dataset
for dfs in list_df_names:

    date_from_dfs_name = dfs[-8:]
    # Converting date str to datetime object
    date_obj = datetime.strptime(date_from_dfs_name, '%Y%m%d')
    # Converting datetime obj to formatted date str
    date_str = date_obj.strftime('%m-%d-%Y')

    # Adding a column with formatted date in the dataset
    locals()[dfs]["Date"]= date_str
    print(dfs, locals()[dfs].shape)
# Out:
# phenocrop_2023_P4M_20m_20230623 (760, 20)
# phenocrop_2023_P4M_20m_20230628 (760, 20)
# phenocrop_2023_P4M_20m_20230708 (760, 20)
# phenocrop_2023_P4M_20m_20230714 (760, 17)
# phenocrop_2023_P4M_20m_20230719 (760, 20)
# phenocrop_2023_P4M_20m_20230727 (760, 20)
# phenocrop_M3MS_20m_20230614 (760, 17)
# Phenocrop_M3MS_20m_20230622 (760, 17)
# phenocrop_M3MS_20m_20230628 (760, 17)
# phenocrop_M3MS_20m_20230708 (760, 17)
# phenocrop_M3MS_20m_20230714 (760, 17)

# %% [markdown]
# # Importing AGRO DATA

# %%
all_files_agro = glob.glob(path_agro + "/*.xls")
all_files_agro
# Out:
# ['C:\\Users\\muij\\OneDrive - Norwegian University of Life Sciences\\Documents\\+Combining ALL DATA with Agro\\PhenoCrop 2023\\AGRO DATA 2023\\23TVollebekk-avling data fra JAD_231106.xls']

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    -------------------------------------- - 92.2/96.5 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 96.5/96.5 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ['23T1A',
#  '23T2A',
#  '23T3B4',
#  '23T4B4',
#  '23T5B4',
#  '23T6B4',
#  '23T7B4',
#  '23T8B4',
#  '23T9B4',
#  '23T10B4',
#  '23T11B4',
#  '23T12B4']

# %%
list_agro_sheets = []
z

for filepath in all_files_agro:
    file_name=os.path.basename(filepath).replace('-','_')
    agro_data_obj = pd.ExcelFile(filepath)
    sheets_in_xls = pd.ExcelFile(filepath).sheet_names

    
    # # print(filepath,os.path.basename(filepath[:-5]))
    # locals()[file_name] = pd.read_excel(filepath, index_col=None, header=0)
    # print(file_name, '=====', locals()[file_name].shape)

# %%
tes_df = agro_data_obj.parse(sheets_in_xls[1])

# %%
# Out:
# True

# %%
# Fixing the column names in the agro data
cols_row1 = tes_df.columns[:].tolist()
cols_row2 = tes_df.iloc[0,:].tolist()

# Eliminating Nan values in the lists
cols_row1 = ['' if pd.isna(x) else x for x in cols_row1]
cols_row2 = ['' if pd.isna(x) else x for x in cols_row2]

# Eliminating unnamed entries in the first column
cols_row1 = ['' if 'Unnamed' in x else x for x in cols_row1]

cols_corrected = list(map(''.join, zip(cols_row1, cols_row2)))

# %%
# Finding the row with all Nan entries since the rows before that one are the column headers
for row in range(tes_df.shape[0]):
    print(row)
    if tes_df.iloc[row,:].isnull().all():
        cutoff_row = row
        break
# Out:
# 0
# 1

# %%
tes_df.columns = cols_corrected
tes_df
# Out:
#      r_expt  r_location  plot  entry            name  \
# 0    r_expt  r_location  plot  entry NaN        name
# 1       NaN         NaN   NaN    NaN NaN         NaN
# 2   23T2A 4   Vollebekk   307      5 NaN   Libertina
# 3   23T2A 4   Vollebekk   308     16 NaN     GN21669
# 4   23T2A 4   Vollebekk   309     11 NaN  SG-S804-19
# 5   23T2A 4   Vollebekk   310     24 NaN     GN22559
# 6   23T2A 4   Vollebekk   311     17 NaN    SW180193
# 7   23T2A 4   Vollebekk   312      6 NaN     GN16554
# 8   23T2A 4   Vollebekk   313     15 NaN     GN21655
# 9   23T2A 4   Vollebekk   314     23 NaN     GN20516
# 10  23T2A 4   Vollebekk   315     10 NaN     GN19557
# 11  23T2A 4   Vollebekk   316     21 NaN     GN21506
# 12  23T2A 4   Vollebekk   317     12 NaN    SW180272
# 13  23T2A 4   Vollebekk   318     18 NaN   SJ20SW114
# 14  23T2A 4   Vollebekk   319     22 NaN     GN21640
# 15  23T2A 4   Vollebekk   320      7 NaN    SW170014
# 16  23T2A 4   Vollebekk   321     14 NaN     GN21509
# 17  23T2A 4   Vollebekk   322      2 NaN      Krabat
# 18  23T2A 4   Vollebekk   323      1 NaN       Zebra
# 19  23T2A 4   Vollebekk   324     19 NaN     GN21520
# 20  23T2A 4   Vollebekk   325      4 NaN    Malvolio
# 21  23T2A 4   Vollebekk   326     20 NaN     GN21675
# 22  23T2A 4   Vollebekk   327     13 NaN     GN21508
# 23  23T2A 4   Vollebekk   328      9 NaN     GN18656
# 24  23T2A 4   Vollebekk   329     25 NaN     GN22601
# 25  23T2A 4   Vollebekk   330      8 NaN   Calispero
# 26  23T2A 4   Vollebekk   331      3 NaN      Betong
# 27  23T2A 4   Vollebekk   407     19 NaN     GN21520
# 28  23T2A 4   Vollebekk   408      7 NaN    SW170014
# 29  23T2A 4   Vollebekk   409     16 NaN     GN21669
# 30  23T2A 4   Vollebekk   410     10 NaN     GN19557
# 31  23T2A 4   Vollebekk   411      8 NaN   Calispero
# 32  23T2A 4   Vollebekk   412      2 NaN      Krabat
# 33  23T2A 4   Vollebekk   413     12 NaN    SW180272
# 34  23T2A 4   Vollebekk   414     23 NaN     GN20516
# 35  23T2A 4   Vollebekk   415      5 NaN   Libertina
# 36  23T2A 4   Vollebekk   416     13 NaN     GN21508
# 37  23T2A 4   Vollebekk   417     21 NaN     GN21506
# 38  23T2A 4   Vollebekk   418      9 NaN     GN18656
# 39  23T2A 4   Vollebekk   419     18 NaN   SJ20SW114
# 40  23T2A 4   Vollebekk   420     11 NaN  SG-S804-19
# 41  23T2A 4   Vollebekk   421     20 NaN     GN21675
# 42  23T2A 4   Vollebekk   422     15 NaN     GN21655
# 43  23T2A 4   Vollebekk   423     25 NaN     GN22601
# 44  23T2A 4   Vollebekk   424     17 NaN    SW180193
# 45  23T2A 4   Vollebekk   425      4 NaN    Malvolio
# 46  23T2A 4   Vollebekk   426     14 NaN     GN21509
# 47  23T2A 4   Vollebekk   427      1 NaN       Zebra
# 48  23T2A 4   Vollebekk   428     22 NaN     GN21640
# 49  23T2A 4   Vollebekk   429      6 NaN     GN16554
# 50  23T2A 4   Vollebekk   430      3 NaN      Betong
# 51  23T2A 4   Vollebekk   431     24 NaN     GN22559
#
#                          pedigree  Legde Pl.høyde Etter-Ren. Akssk.Juni  \
# 0                        pedigree  Legde    høyde       Ren.       Juni
# 1                             NaN    NaN      NaN        NaN        NaN
# 2                             NaN      0       58         10         24
# 3                 GN09584/SW71139      0       70         10         26
# 4                             NaN      0       71         15         27
# 5             GN09648/Demonstrant      0       78         15         27
# 6                             NaN      0       66         15         25
# 7   Bajass-1/GN03529//Demonstrant      0       72         20         26
# 8                 GN10521/SW71139      0       76         15         26
# 9                 SW71139/Berserk      0       65          5         25
# 10                  Zebra/GN07574      0       72          5         26
# 11                SW71139/GN05567      0       72         10         25
# 12                            NaN      0       84          5         28
# 13                            NaN      0       64          5         24
# 14                SW71139/GN05567      0       72          5         26
# 15         SW40251/SW41483xSonett      0       74          2         25
# 16                   QUARNA/Zebra      0       69          5         24
# 17                  T1005/NK93512      0       69          2         25
# 18                   Ralle/Dragon      0       75          2         25
# 19                  Zebra/GN07574      0       74          2         25
# 20                SW51114/SW71124      0       68          2         25
# 21                GN10512/SW71139      0       74          2         26
# 22                SW51114/GN06600      0       79          2         25
# 23                Berserk/SW51127      0       78          5         26
# 24                Amulett/GN07574      0       71          2         25
# 25                    SEC518-08-3     30       78          2         26
# 26         SW44254/Zebra//GN03531      0       72          2         25
# 27                  Zebra/GN07574      0       69          5         26
# 28         SW40251/SW41483xSonett      0       66         10         24
# 29                GN09584/SW71139      0       71         15         26
# 30                  Zebra/GN07574      0       73         10         26
# 31                    SEC518-08-3     10       73         20         26
# 32                  T1005/NK93512      0       70          5         25
# 33                            NaN      0       84         10         28
# 34                SW71139/Berserk      0       68          2         25
# 35                            NaN      0       70          5         24
# 36                SW51114/GN06600      0       79          5         26
# 37                SW71139/GN05567      0       75          2         25
# 38                Berserk/SW51127      2       79          2         27
# 39                            NaN      2       67          5         23
# 40                            NaN      5       77          5         26
# 41                GN10512/SW71139      0       71         10         25
# 42                GN10521/SW71139      0       74         15         26
# 43                Amulett/GN07574      0       74          5         25
# 44                            NaN      0       74          2         25
# 45                SW51114/SW71124      0       75          5         25
# 46                   QUARNA/Zebra      0       72          2         24
# 47                   Ralle/Dragon      0       81          5         25
# 48                SW71139/GN05567      0       79          2         26
# 49  Bajass-1/GN03529//Demonstrant      0       82          5         26
# 50         SW44254/Zebra//GN03531      0       74          2         24
# 51            GN09648/Demonstrant     20       86          2         28
#
#    Gulm.Aug. Rå rute-avling Tørr rute-avling Vanntørr      %Vann Avlingkg/daa
# 0       Aug.         avling           avling     tørr       Vann       kg/daa
# 1        NaN            NaN              NaN      NaN        NaN          NaN
# 2         19           3.52             3044     11.7  23.640568   421.623843
# 3         21           4.68             4101     11.7  22.624295   568.028706
# 4         21           3.72             3303     11.7  21.598145   457.497882
# 5         22            4.6             4015     11.7  22.929457   556.116863
# 6         24           4.07             3557     11.7  22.829705   492.679373
# 7         21            4.3             3791     11.7  22.152256   525.090667
# 8         24           5.09             4500     11.7  21.935167   623.294118
# 9         22           4.94             4407     11.7  21.227105   610.412706
# 10        21           4.69             4200     11.7  20.925373   581.741176
# 11        19           4.78             4281     11.7  20.917929   592.960471
# 12        22            5.2             4473     11.7  24.045019   619.554353
# 13        21           4.08             3556     11.7   23.04049   492.540863
# 14        22           5.38             4732     11.7   22.33539   655.428392
# 15        19           4.74             4312     11.7   19.67308   597.254275
# 16        17           4.77             4330     11.7  19.845073   599.747451
# 17        15           4.29             3911     11.7  19.500862   541.711843
# 18        17           4.29             3907     11.7  19.583193   541.157804
# 19        16           4.79             4428     11.7  18.373194   613.321412
# 20        17           4.73             4344     11.7  18.905877   601.686588
# 21        20           5.05             4609     11.7   19.41095   638.391686
# 22        20            5.1             4618     11.7  20.045216   639.638275
# 23        21           5.13             4750     11.7  18.240741   657.921569
# 24        20           4.94             4517     11.7  19.260911   625.648784
# 25        21           4.76             4367     11.7  18.990315   604.872314
# 26        21           4.84             4456     11.7   18.70562   617.199686
# 27        18           4.23             3838     11.7  19.882884   531.600627
# 28        21            4.3             3808     11.7  21.803163   527.445333
# 29        22           5.13             4541     11.7  21.838148    628.97302
# 30        20           4.78             4248     11.7  21.527531   588.389647
# 31        21            4.4             3836     11.7  23.018455   531.323608
# 32        17           4.42             3999     11.7  20.110475   553.900706
# 33        22           5.51             4740     11.7  24.039564   656.536471
# 34        22           5.38             4741     11.7  22.187677    656.67498
# 35        21           4.84             4357     11.7  20.511756   603.487216
# 36        21           5.27             4690     11.7  21.418027    649.61098
# 37        22           5.28             4809     11.7  19.576761   666.093647
# 38        21           5.34             4817     11.7  20.348109   667.201725
# 39        20           4.59             4066     11.7  21.780436   563.180863
# 40        22           5.06             4402     11.7   23.18249   609.720157
# 41        20           5.04             4549     11.7  20.302242   630.081098
# 42        21           5.36             4875     11.7  19.689832   675.235294
# 43        20           4.92             4407     11.7   20.90689   610.412706
# 44        21           5.08             4619     11.7  19.713051   639.776784
# 45        20           5.36             4907     11.7  19.162668   679.667608
# 46        19           5.46             5092     11.7  17.651355   705.291922
# 47        19           4.91             4564     11.7  17.922363   632.158745
# 48        21           5.94             5401     11.7  19.712407   748.091451
# 49        21           5.32             4853     11.7  19.451147   672.188078
# 50        21           5.37             4966     11.7  18.343054   687.839686
# 51        22           5.71             5097     11.7  21.179492   705.984471

# %%
tes_df.shape[0]
# Out:
# 52

# %%
import os
for filename in all_files_qgis:

    print(os.path.basename(filename[-13:-5]))
# Out:
# 20230623
# 20230628
# 20230708
# 20230714
# 20230719
# 20230727
# 20230614
# 20230622
# 20230628
# 20230708
# 20230714
# 20230601
# 20230707
# 20230707
# 20230714
# 20230714
# 20230816
# 20230816
# 20230719
# 20230719
# 20230725
# 20230725
# 20230628

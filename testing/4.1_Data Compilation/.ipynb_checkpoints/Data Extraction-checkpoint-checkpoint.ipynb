# %%
import pandas as pd
import glob

# %%
path_qgis = r'P:\Phenocrop_2023\3_stats\phenocrop'

# %%
path_agro = r'P:\PhenoCrop\Agro Data\PhenoCrop 2023'

# %%
path
# Out:
# 'P:\\PhenoCrop\\Agro Data\\PhenoCrop 2023'

# %%
all_files = glob.glob(path + "/*.xlsx")

# %%
# Importing all the datasets except those from Mavic3RGB images since we need the Multispectral data only


li = []
list_df_names = []
for filepath in all_files:
    if not("M3RGB") in filepath:
        file_name=os.path.basename(filepath[:-5]).replace('-','_')
        list_df_names.append(file_name)
        
        # print(filepath,os.path.basename(filepath[:-5]))
        locals()[file_name] = pd.read_excel(filepath, index_col=None, header=0)
        print(file_name, '=====', locals()[file_name].shape)
# Out:
# phenocrop_2023_P4M_20m_20230623 ===== (760, 19)
# phenocrop_2023_P4M_20m_20230628 ===== (760, 19)
# phenocrop_2023_P4M_20m_20230708 ===== (760, 40)
# phenocrop_2023_P4M_20m_20230714 ===== (760, 16)
# phenocrop_2023_P4M_20m_20230719 ===== (760, 19)
# phenocrop_2023_P4M_20m_20230727 ===== (760, 19)
# phenocrop_M3MS_20m_20230614 ===== (760, 16)
# Phenocrop_M3MS_20m_20230622 ===== (760, 16)
# phenocrop_M3MS_20m_20230628 ===== (760, 16)
# phenocrop_M3MS_20m_20230708 ===== (760, 16)
# phenocrop_M3MS_20m_20230714 ===== (760, 16)

# %%
for dfs in list_df_names:
    locals()dfs["Date"]=

# %%
phenocrop_M3MS_20m_20230708["Date"]="phenocrop_M3MS_20m_20230708"[-8:]

# %%
phenocrop_M3MS_20m_20230708
# Out:
#       id  green_mean  green_median  green_stdev  nir_mean  nir_median  \
# 0    101    0.046896      0.045419     0.010317  0.352626    0.352081
# 1    102    0.043021      0.042146     0.011757  0.349071    0.358184
# 2    103    0.046572      0.045742     0.009238  0.374044    0.377911
# 3    104    0.044587      0.043499     0.010123  0.361871    0.365952
# 4    105    0.046271      0.045137     0.008779  0.373456    0.373821
# ..   ...         ...           ...          ...       ...         ...
# 755  891    0.046774      0.045587     0.010471  0.377087    0.377450
# 756  892    0.043599      0.042171     0.010796  0.392108    0.393065
# 757  893    0.046769      0.046932     0.012131  0.363974    0.380002
# 758  894    0.047876      0.046977     0.010132  0.383221    0.383457
# 759  895    0.045428      0.045298     0.012610  0.329692    0.349436
#
#      nir_stdev  red_edge_mean  red_edge_median  red_edge_stdev  red_mean  \
# 0     0.051798       0.146879         0.144408        0.028266  0.032538
# 1     0.074580       0.144157         0.144060        0.036822  0.028165
# 2     0.056334       0.159584         0.158342        0.029068  0.030179
# 3     0.058326       0.156412         0.154991        0.031941  0.027760
# 4     0.045108       0.157990         0.155626        0.025995  0.029785
# ..         ...            ...              ...             ...       ...
# 755   0.055470       0.152899         0.151440        0.028665  0.031450
# 756   0.058455       0.151295         0.149378        0.029631  0.026913
# 757   0.083673       0.145114         0.148657        0.035868  0.031910
# 758   0.061017       0.150141         0.148823        0.028811  0.032023
# 759   0.090639       0.129486         0.133242        0.037001  0.032883
#
#      red_median  red_stdev  ndvi_mean  ndvi_median  ndvi_stdev      Date
# 0      0.031638   0.006794   0.831334     0.832630    0.021967  20230708
# 1      0.027712   0.007172   0.849076     0.851821    0.027936  20230708
# 2      0.029700   0.005590   0.850006     0.852503    0.021288  20230708
# 3      0.027212   0.005979   0.857164     0.858843    0.021573  20230708
# 4      0.029128   0.005485   0.852501     0.853291    0.017737  20230708
# ..          ...        ...        ...          ...         ...       ...
# 755    0.030697   0.006826   0.846474     0.847906    0.020491  20230708
# 756    0.026278   0.006321   0.871981     0.873777    0.019571  20230708
# 757    0.031937   0.007618   0.836078     0.839988    0.027984  20230708
# 758    0.031707   0.006322   0.845192     0.845198    0.022237  20230708
# 759    0.032673   0.008249   0.810766     0.821966    0.050704  20230708
#
# [760 rows x 17 columns]

# %%
for dfs in list_df_names:
    print(locals()[dfs].shape)
# Out:
# (760, 19)
# (760, 19)
# (760, 40)
# (760, 16)
# (760, 19)
# (760, 19)
# (760, 16)
# (760, 16)
# (760, 16)
# (760, 16)
# (760, 16)

# %%
locals()[dfs].shape
# Out:
# (760, 19)

# %%
phenocrop_2023_P4M_20m_20230628
# Out:
#       id  ndvi_mean  ndvi_median  ndvi_stdev  blue_mean  blue_median  \
# 0    101   0.592851     0.600625    0.065406   0.005977     0.005829
# 1    102   0.632470     0.654520    0.099205   0.004738     0.004587
# 2    103   0.626782     0.639923    0.072387   0.005744     0.005679
# 3    104   0.663863     0.676744    0.068780   0.004888     0.004792
# 4    105   0.643405     0.647937    0.050192   0.005634     0.005545
# ..   ...        ...          ...         ...        ...          ...
# 755  891   0.659837     0.667184    0.062882   0.005199     0.005065
# 756  892   0.705066     0.714711    0.063722   0.004429     0.004325
# 757  893   0.611708     0.634162    0.102111   0.005354     0.005264
# 758  894   0.623379     0.632607    0.073298   0.005826     0.005731
# 759  895   0.550913     0.597028    0.152242   0.005471     0.005355
#
#      blue_stdev  green_mean  green_median  green_stdev  nir_mean  nir_median  \
# 0      0.001479    0.005439      0.005292     0.001350  0.015797    0.015854
# 1      0.001223    0.004799      0.004675     0.001334  0.015075    0.015233
# 2      0.001145    0.005650      0.005582     0.001221  0.017206    0.017419
# 3      0.001064    0.005117      0.005008     0.001261  0.016572    0.016734
# 4      0.001154    0.005461      0.005385     0.001139  0.016977    0.017016
# ..          ...         ...           ...          ...       ...         ...
# 755    0.001339    0.004847      0.004736     0.001271  0.016454    0.016423
# 756    0.001065    0.004514      0.004395     0.001220  0.016687    0.016768
# 757    0.001412    0.004900      0.004856     0.001359  0.015118    0.015627
# 758    0.001336    0.005490      0.005375     0.001343  0.016697    0.016818
# 759    0.001535    0.004937      0.004872     0.001440  0.014032    0.014553
#
#      nir_stdev  red_edge_mean  red_edge_median  red_edge_stdev  red_mean  \
# 0     0.003732       0.009831         0.009766        0.002331  0.003977
# 1     0.004457       0.009314         0.009302        0.002690  0.003231
# 2     0.003575       0.010721         0.010724        0.002174  0.003880
# 3     0.003886       0.010256         0.010243        0.002430  0.003274
# 4     0.003151       0.010591         0.010551        0.002034  0.003658
# ..         ...            ...              ...             ...       ...
# 755   0.003717       0.009811         0.009702        0.002319  0.003343
# 756   0.003762       0.009962         0.009908        0.002401  0.002846
# 757   0.004511       0.009428         0.009612        0.002765  0.003452
# 758   0.003728       0.010586         0.010512        0.002430  0.003815
# 759   0.004978       0.008875         0.009029        0.002910  0.003727
#
#      red_median  red_stdev
# 0      0.003873   0.000921
# 1      0.003136   0.000843
# 2      0.003820   0.000831
# 3      0.003209   0.000765
# 4      0.003612   0.000742
# ..          ...        ...
# 755    0.003247   0.000884
# 756    0.002755   0.000766
# 757    0.003387   0.000889
# 758    0.003719   0.000925
# 759    0.003643   0.001028
#
# [760 rows x 19 columns]

# %%
phenocrop_2023_P4M_20m_20230628
# Out:
#       id  ndvi_mean  ndvi_median  ndvi_stdev  blue_mean  blue_median  \
# 0    101   0.592851     0.600625    0.065406   0.005977     0.005829
# 1    102   0.632470     0.654520    0.099205   0.004738     0.004587
# 2    103   0.626782     0.639923    0.072387   0.005744     0.005679
# 3    104   0.663863     0.676744    0.068780   0.004888     0.004792
# 4    105   0.643405     0.647937    0.050192   0.005634     0.005545
# ..   ...        ...          ...         ...        ...          ...
# 755  891   0.659837     0.667184    0.062882   0.005199     0.005065
# 756  892   0.705066     0.714711    0.063722   0.004429     0.004325
# 757  893   0.611708     0.634162    0.102111   0.005354     0.005264
# 758  894   0.623379     0.632607    0.073298   0.005826     0.005731
# 759  895   0.550913     0.597028    0.152242   0.005471     0.005355
#
#      blue_stdev  green_mean  green_median  green_stdev  nir_mean  nir_median  \
# 0      0.001479    0.005439      0.005292     0.001350  0.015797    0.015854
# 1      0.001223    0.004799      0.004675     0.001334  0.015075    0.015233
# 2      0.001145    0.005650      0.005582     0.001221  0.017206    0.017419
# 3      0.001064    0.005117      0.005008     0.001261  0.016572    0.016734
# 4      0.001154    0.005461      0.005385     0.001139  0.016977    0.017016
# ..          ...         ...           ...          ...       ...         ...
# 755    0.001339    0.004847      0.004736     0.001271  0.016454    0.016423
# 756    0.001065    0.004514      0.004395     0.001220  0.016687    0.016768
# 757    0.001412    0.004900      0.004856     0.001359  0.015118    0.015627
# 758    0.001336    0.005490      0.005375     0.001343  0.016697    0.016818
# 759    0.001535    0.004937      0.004872     0.001440  0.014032    0.014553
#
#      nir_stdev  red_edge_mean  red_edge_median  red_edge_stdev  red_mean  \
# 0     0.003732       0.009831         0.009766        0.002331  0.003977
# 1     0.004457       0.009314         0.009302        0.002690  0.003231
# 2     0.003575       0.010721         0.010724        0.002174  0.003880
# 3     0.003886       0.010256         0.010243        0.002430  0.003274
# 4     0.003151       0.010591         0.010551        0.002034  0.003658
# ..         ...            ...              ...             ...       ...
# 755   0.003717       0.009811         0.009702        0.002319  0.003343
# 756   0.003762       0.009962         0.009908        0.002401  0.002846
# 757   0.004511       0.009428         0.009612        0.002765  0.003452
# 758   0.003728       0.010586         0.010512        0.002430  0.003815
# 759   0.004978       0.008875         0.009029        0.002910  0.003727
#
#      red_median  red_stdev
# 0      0.003873   0.000921
# 1      0.003136   0.000843
# 2      0.003820   0.000831
# 3      0.003209   0.000765
# 4      0.003612   0.000742
# ..          ...        ...
# 755    0.003247   0.000884
# 756    0.002755   0.000766
# 757    0.003387   0.000889
# 758    0.003719   0.000925
# 759    0.003643   0.001028
#
# [760 rows x 19 columns]

# %%
list_df_names
# Out:
# ['phenocrop_2023_P4M_20m_20230623',
#  'phenocrop_2023_P4M_20m_20230628',
#  'phenocrop_2023_P4M_20m_20230708',
#  'phenocrop_2023_P4M_20m_20230714',
#  'phenocrop_2023_P4M_20m_20230719',
#  'phenocrop_2023_P4M_20m_20230727',
#  'phenocrop_M3MS_20m_20230614',
#  'Phenocrop_M3MS_20m_20230622',
#  'phenocrop_M3MS_20m_20230628',
#  'phenocrop_M3MS_20m_20230708',
#  'phenocrop_M3MS_20m_20230714']

# %%
phenocrop-2023-P4M_20m_20230623
# Out:
#   Cell In[51], line 1
#     phenocrop-2023-P4M-20m-20230623
#                         ^
# SyntaxError: invalid decimal literal

# %%
list_df_names[0]=li[1]

# %%
import os
for filename in all_files:

    print(os.path.basename(filename[-13:-5]))
# Out:
# 20230623
# 20230628
# 20230708
# 20230714
# 20230719
# 20230727
# 20230614
# 20230622
# 20230628
# 20230708
# 20230714
# 20230601
# 20230707
# 20230707
# 20230714
# 20230714
# 20230816
# 20230816
# 20230719
# 20230719
# 20230725
# 20230725
# 20230628

# %% [markdown]
# # Downscaling all the Orthomosaics for all projects (RGB & NDVI)

# %%
import os
import rasterio
from rasterio.enums import Resampling

# %%
def find_orthomosaic_files(root_folder, search_config):
    """
    Finds orthomosaic files based on a dictionary defining search criteria.

    Parameters:
        root_folder (str): The directory containing multiple field_name subfolders.
        search_config (dict): Dictionary where keys are labels (e.g., "NDVI") 
                              and values are tuples (suffix, scale_factor).

    Returns:
        dict: {key_word: [list of matching file paths]}
    """
    matching_files = {key: [] for key in search_config}

    for field_name in os.listdir(root_folder):
        field_path = os.path.join(root_folder, field_name)

        if os.path.isdir(field_path):
            ms_folder = os.path.join(field_path, "MS WORK STATION")
            
            if os.path.isdir(ms_folder):
                for flight_folder in os.listdir(ms_folder):
                    flight_path = os.path.join(ms_folder, flight_folder)

                    if os.path.isdir(flight_path):
                        orthomosaic_folder = os.path.join(flight_path, "2_Orthomosaics")

                        if os.path.isdir(orthomosaic_folder):
                            for file in os.listdir(orthomosaic_folder):
                                for key_word, (suffix, _) in search_config.items():
                                    if file.endswith(suffix):
                                        matching_files[key_word].append(os.path.join(orthomosaic_folder, file))

    return matching_files

# %%
def rotate_image(image_array, angle):
    """Rotate an image by a given angle."""
    return rotate(image_array, angle, resize=True, mode='edge')

def preview_rotation(file_path, angle):
    """
    Rotates the first image and displays a preview.
    Returns the rotated image array for saving.
    """
    with rasterio.open(file_path) as src:
        image_array = src.read(1).astype(np.float32)
        rotated_array = rotate_image(image_array, angle)

    # Display the preview
    plt.figure(figsize=(6, 6))
    plt.imshow(rotated_array, cmap="gray")
    plt.title(f"Preview: Rotated {angle}°")
    plt.axis("off")
    plt.show()

    return rotated_array

# %%
def downscale_image(file_path, output_folder, scale_factor):
    """
    Downscale a TIFF/JPG file and save it in the structured output directory.

    Parameters:
        file_path (str): The path to the original file.
        output_folder (str): The base output folder.
        scale_factor (float): Scaling factor (e.g., 0.25 for 25%).

    Returns:
        str: Path to the saved downscaled file.
    """
    print(f"\n⚙️ Processing: {os.path.basename(file_path)} at {int(scale_factor * 100)}% resolution")

    try:
        with rasterio.open(file_path) as src:
            # Compute new dimensions
            new_width = int(src.width * scale_factor)
            new_height = int(src.height * scale_factor)
            print(f"   - Original size: {src.width} x {src.height}")
            print(f"   - New size: {new_width} x {new_height}")

            # Read and resample image
            resampled_array = src.read(
                out_shape=(src.count, new_height, new_width),
                resampling=Resampling.bilinear
            )

            # Update metadata
            profile = src.profile
            profile.update(
                width=new_width,
                height=new_height,
                transform=src.transform * src.transform.scale(
                    (src.width / new_width), (src.height / new_height)
                )
            )

            # Extract field_name from file path
            field_name = os.path.basename(os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(file_path)))))
            
            # Identify file type (TIFF/JPG) based on extension
            file_ext = os.path.splitext(file_path)[-1].lower()

            # Determine key_word (e.g., "NDVI", "RGB") based on the dictionary
            key_word = next((k for k, (suffix, _) in search_config.items() if file_path.endswith(suffix)), "Unknown")

            # Create structured output directory
            final_output_folder = os.path.join(output_folder, field_name, key_word)
            os.makedirs(final_output_folder, exist_ok=True)

            # Generate output filename
            output_scaled_path = os.path.join(
                final_output_folder,
                os.path.basename(file_path).replace(file_ext, f"_{int(scale_factor * 100)}%{file_ext}")
            )

            # Save downscaled image
            print(f"   - Saving downscaled file: {output_scaled_path}")
            with rasterio.open(output_scaled_path, "w", **profile) as dst:
                dst.write(resampled_array)

            print(f"✅ Successfully downscaled: {os.path.basename(file_path)}")
            return output_scaled_path

    except Exception as e:
        print(f"❌ ERROR processing {file_path}: {str(e)}")
        return None

# %%
# Example Usage
root_folder = r"D:\PhenoCrop\2_pix4d"  # Change to your actual root folder
output_folder = r"D:\PhenoCrop\2_2_Orthomosaics_resized"  # Base output directory

# Define search criteria with scale factors
search_config = {
    "RGB": ("_transparent_mosaic_group1.tif", 0.25), # JPG files scaled to 25%
    "NDVI": ("_index_ndvi.tif", 0.5), # TIFF files scaled to 50%
#     "Green": ("_index_green_green.tif", 0.5),
#     "NIR": ("_index_nir_nir.tif", 0.5),
#     "RedEdge": ("_index_red_edge_red_edge.tif", 0.5),
#     "Red": ("_index_red_red.tif", 0.5)
}

# Step 1: Find orthomosaic files
orthomosaic_files = find_orthomosaic_files(root_folder, search_config)
orthomosaic_files
# Out:
# {'RGB': ['D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240603 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240603 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240603 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240603 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240607 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240607 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240607 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240607 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240611 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240611 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240611 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240611 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240620 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240620 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240620 OAT_FRONTIERS M3M 30m MS 80 85_old\\2_Orthomosaics\\20240620 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240621 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240621 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240624 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240624 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240624 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240624 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240702 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240702 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240703 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240703 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240708 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240708 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240708 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240708 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240718 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240718 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240718 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240718 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240724 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240724 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240724 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240724 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240729 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240729 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240729 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240729 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240805 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240805 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240806 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240806 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240812 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240812 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240812 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240812 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240819 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240819 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240819 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240819 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240826 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240826 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif'],
#  'NDVI': ['D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240603 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240603 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240603 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240603 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240607 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240607 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240607 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240607 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240611 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240611 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240611 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240611 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240620 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240620 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240620 OAT_FRONTIERS M3M 30m MS 80 85_old\\2_Orthomosaics\\20240620 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240621 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240621 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240624 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240624 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240624 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240624 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240702 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240702 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240703 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240703 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240708 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240708 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240708 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240708 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240718 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240718 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240718 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240718 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240724 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240724 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240724 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240724 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240729 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240729 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240729 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240729 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240805 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240805 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240806 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240806 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240812 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240812 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240812 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240812 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240819 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240819 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240819 OAT_FRONTIERS M3M 30m MS 80 85\\2_Orthomosaics\\20240819 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif',
#   'D:\\PhenoCrop\\2_pix4d\\OAT_FRONTIERS\\MS WORK STATION\\20240826 OAT_FRONTIERS M3M 20m MS 80 85\\2_Orthomosaics\\20240826 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif']}

# %%
# Step 2: Process each file with corresponding scale factor
for key_word, file_list in orthomosaic_files.items():
    print(f"\n🔍 Processing {key_word} files...")
    for file_path in file_list:
        suffix, scale_factor = search_config[key_word]
        downscale_image(file_path, output_folder, scale_factor)
# Out:
# 🔍 Processing RGB files...
#
# ⚙️ Processing: 20240603 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 10095 x 11182
#    - New size: 2523 x 2795
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240603 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240603 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240603 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 7084 x 7449
#    - New size: 1771 x 1862
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240603 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240603 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240607 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 10271 x 11088
#    - New size: 2567 x 2772
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240607 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240607 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240607 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 7540 x 8082
#    - New size: 1885 x 2020
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240607 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240607 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240611 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 10225 x 10614
#    - New size: 2556 x 2653
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240611 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240611 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240611 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 7398 x 7945
#    - New size: 1849 x 1986
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240611 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240611 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240620 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 6787 x 6981
#    - New size: 1696 x 1745
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240620 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240620 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240620 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 6787 x 6981
#    - New size: 1696 x 1745
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240620 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240620 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240621 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 10059 x 10594
#    - New size: 2514 x 2648
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240621 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240621 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240624 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 9231 x 10052
#    - New size: 2307 x 2513
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240624 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240624 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240624 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 6959 x 7430
#    - New size: 1739 x 1857
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240624 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240624 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240702 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 9247 x 9779
#    - New size: 2311 x 2444
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240702 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240702 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240703 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 7043 x 7664
#    - New size: 1760 x 1916
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240703 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240703 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240708 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 8864 x 9873
#    - New size: 2216 x 2468
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240708 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240708 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240708 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 6586 x 7262
#    - New size: 1646 x 1815
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240708 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240708 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240718 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 8558 x 9508
#    - New size: 2139 x 2377
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240718 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240718 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240718 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 6426 x 7223
#    - New size: 1606 x 1805
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240718 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240718 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240724 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 8499 x 9575
#    - New size: 2124 x 2393
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240724 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240724 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240724 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 6164 x 7033
#    - New size: 1541 x 1758
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240724 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240724 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240729 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 10059 x 10971
#    - New size: 2514 x 2742
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240729 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240729 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240729 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 7172 x 7761
#    - New size: 1793 x 1940
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240729 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240729 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240805 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 9877 x 10426
#    - New size: 2469 x 2606
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240805 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240805 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240806 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 7214 x 7725
#    - New size: 1803 x 1931
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240806 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240806 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240812 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 9994 x 10625
#    - New size: 2498 x 2656
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240812 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240812 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240812 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 7451 x 7903
#    - New size: 1862 x 1975
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240812 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240812 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240819 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 10206 x 11019
#    - New size: 2551 x 2754
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240819 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240819 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240819 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 7470 x 7821
#    - New size: 1867 x 1955
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240819 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240819 OAT_FRONTIERS M3M 30m MS 80 85_transparent_mosaic_group1.tif
#
# ⚙️ Processing: 20240826 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif at 25% resolution
#    - Original size: 11278 x 11315
#    - New size: 2819 x 2828
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\RGB\20240826 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1_25%.tif
# ✅ Successfully downscaled: 20240826 OAT_FRONTIERS M3M 20m MS 80 85_transparent_mosaic_group1.tif
#
# 🔍 Processing NDVI files...
#
# ⚙️ Processing: 20240603 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 10095 x 11182
#    - New size: 5047 x 5591
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240603 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240603 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240603 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 7084 x 7449
#    - New size: 3542 x 3724
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240603 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240603 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240607 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 10271 x 11088
#    - New size: 5135 x 5544
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240607 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240607 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240607 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 7540 x 8082
#    - New size: 3770 x 4041
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240607 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240607 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240611 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 10225 x 10614
#    - New size: 5112 x 5307
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240611 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240611 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240611 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 7398 x 7945
#    - New size: 3699 x 3972
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240611 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240611 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240620 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 6787 x 6981
#    - New size: 3393 x 3490
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240620 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240620 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240620 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 6787 x 6981
#    - New size: 3393 x 3490
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240620 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240620 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240621 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 10059 x 10594
#    - New size: 5029 x 5297
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240621 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240621 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240624 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 9231 x 10052
#    - New size: 4615 x 5026
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240624 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240624 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240624 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 6959 x 7430
#    - New size: 3479 x 3715
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240624 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240624 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240702 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 9247 x 9779
#    - New size: 4623 x 4889
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240702 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240702 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240703 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 7043 x 7664
#    - New size: 3521 x 3832
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240703 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240703 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240708 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 8864 x 9873
#    - New size: 4432 x 4936
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240708 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240708 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240708 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 6586 x 7262
#    - New size: 3293 x 3631
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240708 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240708 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240718 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 8558 x 9508
#    - New size: 4279 x 4754
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240718 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240718 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240718 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 6426 x 7223
#    - New size: 3213 x 3611
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240718 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240718 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240724 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 8499 x 9575
#    - New size: 4249 x 4787
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240724 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240724 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240724 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 6164 x 7033
#    - New size: 3082 x 3516
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240724 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240724 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240729 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 10059 x 10971
#    - New size: 5029 x 5485
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240729 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240729 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240729 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 7172 x 7761
#    - New size: 3586 x 3880
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240729 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240729 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240805 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 9877 x 10426
#    - New size: 4938 x 5213
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240805 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240805 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240806 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 7214 x 7725
#    - New size: 3607 x 3862
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240806 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240806 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240812 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 9994 x 10625
#    - New size: 4997 x 5312
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240812 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240812 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240812 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 7451 x 7903
#    - New size: 3725 x 3951
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240812 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240812 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240819 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 10206 x 11019
#    - New size: 5103 x 5509
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240819 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240819 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240819 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 7470 x 7821
#    - New size: 3735 x 3910
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240819 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240819 OAT_FRONTIERS M3M 30m MS 80 85_index_ndvi.tif
#
# ⚙️ Processing: 20240826 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif at 50% resolution
#    - Original size: 11278 x 11315
#    - New size: 5639 x 5657
#    - Saving downscaled file: D:\PhenoCrop\2_2_Orthomosaics_resized\OAT_FRONTIERS\NDVI\20240826 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi_50%.tif
# ✅ Successfully downscaled: 20240826 OAT_FRONTIERS M3M 20m MS 80 85_index_ndvi.tif

# %% [markdown]
# # Rotate Ortho at a certain angle

# %%
# User-defined rotation angles per project (if available)
rotation_dict = {
     'PHENO_CROP': -13.5,
     'OAT_FRONTIERS': -13.5,
     'DIVERSITY_OATS': -13.5,
     'PRO_BAR_VOLL': -29.5,
     'E166': -115.5,
     'PRO_BAR_SØRÅS': -68.5
}
